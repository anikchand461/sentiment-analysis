# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/Users/anikchand/Documents/sentiment-analysis/IMDB_Dataset.csv')

# %%
df
# Out:
#                                                   review sentiment
# 0      One of the other reviewers has mentioned that ...  positive
# 1      A wonderful little production. <br /><br />The...  positive
# 2      I thought this was a wonderful way to spend ti...  positive
# 3      Basically there's a family where a little boy ...  negative
# 4      Petter Mattei's "Love in the Time of Money" is...  positive
# ...                                                  ...       ...
# 49995  I thought this movie did a down right good job...  positive
# 49996  Bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  I am a Catholic taught in parochial elementary...  negative
# 49998  I'm going to have to disagree with the previou...  negative
# 49999  No one expects the Star Trek movies to be high...  negative
#
# [50000 rows x 2 columns]

# %%
df['review'][0]
# Out:
# "One of the other reviewers has mentioned that after watching just 1 Oz episode you'll be hooked. They are right, as this is exactly what happened with me.<br /><br />The first thing that struck me about Oz was its brutality and unflinching scenes of violence, which set in right from the word GO. Trust me, this is not a show for the faint hearted or timid. This show pulls no punches with regards to drugs, sex or violence. Its is hardcore, in the classic use of the word.<br /><br />It is called OZ as that is the nickname given to the Oswald Maximum Security State Penitentary. It focuses mainly on Emerald City, an experimental section of the prison where all the cells have glass fronts and face inwards, so privacy is not high on the agenda. Em City is home to many..Aryans, Muslims, gangstas, Latinos, Christians, Italians, Irish and more....so scuffles, death stares, dodgy dealings and shady agreements are never far away.<br /><br />I would say the main appeal of the show is due to the 
# ...

# %% [markdown]
# ## Text cleaning
# 1. sample 10000 rows
# 2. remove html tags
# 3. remove special characters
# 4. converting every thing to lower case
# 5. Removing stop words
# 6. Stemming

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   review     50000 non-null  object
#  1   sentiment  50000 non-null  object
# dtypes: object(2)
# memory usage: 781.4+ KB

# %%
df['sentiment'].replace({'positive':1, 'negative':0}, inplace=True)
# Out:
# /var/folders/0p/vdvp33851vn1jcfb8t3_kyzm0000gn/T/ipykernel_25795/3199577391.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['sentiment'].replace({'positive':1, 'negative':0}, inplace=True)
# ...

# %%
df.head()
# Out:
#                                               review  sentiment
# 0  One of the other reviewers has mentioned that ...          1
# 1  A wonderful little production. <br /><br />The...          1
# 2  I thought this was a wonderful way to spend ti...          1
# 3  Basically there's a family where a little boy ...          0
# 4  Petter Mattei's "Love in the Time of Money" is...          1

# %%
df['review'][5207]

s = 'Well, TiVo recorded this because of Angelina Jolie. It had 2.5 stars. It seemed promising. It went downhill fast.<br /><br />There is much overacting, even from Angelina. She\'s about 20 and playing a 16 year old. There are three characters that are supposed to be Italian. Everyone else is Italian- American. The native Italian accents were good, I thought. The young male lead is cute, my wife says. Everyone else in this movie is a fat Italian woman. Even the men.<br /><br />I should have known that when Dick Van Patten was cast as a randy doctor, that that was a bad sign. The two couples chasing their kids around are like the four Italian Stooges.<br /><br />My wife would not let go of the remote. Hopefully she was not taking makeup, clothing or decorating tips. It was a sick and twisted combination of hideous and garish. It was hidegarishous.<br /><br />Cutting off my left ventricle was not sufficient to distract from the pain of watching this movie. If this movie shows up on your TV, do yourself a favor and ram your head through the TV screen instead. You\'ll be glad you did. The only movie I\'ve ever seen that was worse than this was "Hamburger: The Movie". Or maybe "Deadly Friend".'

# %%
import re

clean = re.compile('<.*?>')

re.sub(clean, '', s)
# Out:
# 'Well, TiVo recorded this because of Angelina Jolie. It had 2.5 stars. It seemed promising. It went downhill fast.There is much overacting, even from Angelina. She\'s about 20 and playing a 16 year old. There are three characters that are supposed to be Italian. Everyone else is Italian- American. The native Italian accents were good, I thought. The young male lead is cute, my wife says. Everyone else in this movie is a fat Italian woman. Even the men.I should have known that when Dick Van Patten was cast as a randy doctor, that that was a bad sign. The two couples chasing their kids around are like the four Italian Stooges.My wife would not let go of the remote. Hopefully she was not taking makeup, clothing or decorating tips. It was a sick and twisted combination of hideous and garish. It was hidegarishous.Cutting off my left ventricle was not sufficient to distract from the pain of watching this movie. If this movie shows up on your TV, do yourself a favor and ram your head throug
# ...

# %%
# function to clean html codes

def clean_html(text):
    clean = re.compile('<.*?>')
    return re.sub(clean, '', text)

# %%
df['review'] = df['review'].apply(clean_html)

# %%
# converting everything to lower

def convert_lower(text):
    return text.lower()

# %%
df['review'] = df['review'].apply(convert_lower)

# %%
# to remove special characters

def remove_special(text):
    x = ''
    
    for i in text:
        if i.isalnum():
            x += i
        else:
            x += ' '
    
    return x

# %%
remove_special("hjgajhsd5$#34*snjfds(sdhfj[SFj]bsdbf\\sf)")
# Out:
# 'hjgajhsd5  34 snjfds sdhfj SFj bsdbf sf '

# %%
df['review'] = df['review'].apply(remove_special)

# %%
import sys
# !{sys.executable} -m pip install nltk
# Out:
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python3.10 -m pip install --upgrade pip

# %%
# remove the stop words
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/anikchand/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

# %%
stopwords.words('english')
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
def remove_stopwords(text):
    x = []
    for i in text.split():
        
        if i not in stopwords.words('english'):
            x.append(i)
    
    y = x[:]
    x.clear()
    return y

# %%
df['review'] = df['review'].apply(remove_stopwords)

# %%
df
# Out:
#                                                   review  sentiment
# 0      [one, reviewers, mentioned, watching, 1, oz, e...          1
# 1      [wonderful, little, production, filming, techn...          1
# 2      [thought, wonderful, way, spend, time, hot, su...          1
# 3      [basically, family, little, boy, jake, thinks,...          0
# 4      [petter, mattei, love, time, money, visually, ...          1
# ...                                                  ...        ...
# 49995  [thought, movie, right, good, job, creative, o...          1
# 49996  [bad, plot, bad, dialogue, bad, acting, idioti...          0
# 49997  [catholic, taught, parochial, elementary, scho...          0
# 49998  [going, disagree, previous, comment, side, mal...          0
# 49999  [one, expects, star, trek, movies, high, art, ...          0
#
# [50000 rows x 2 columns]

# %%
# perform stemming

from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
y = []
def stem_words(text):
    for i in text:
        y.append(ps.stem(i))
    z = y[:]
    y.clear()
    return z

# %%
df['review'] = df['review'].apply(stem_words)

# %%
df
# Out:
#                                                   review  sentiment
# 0      [one, review, mention, watch, 1, oz, episod, h...          1
# 1      [wonder, littl, product, film, techniqu, unass...          1
# 2      [thought, wonder, way, spend, time, hot, summe...          1
# 3      [basic, famili, littl, boy, jake, think, zombi...          0
# 4      [petter, mattei, love, time, money, visual, st...          1
# ...                                                  ...        ...
# 49995  [thought, movi, right, good, job, creativ, ori...          1
# 49996  [bad, plot, bad, dialogu, bad, act, idiot, dir...          0
# 49997  [cathol, taught, parochi, elementari, school, ...          0
# 49998  [go, disagre, previou, comment, side, maltin, ...          0
# 49999  [one, expect, star, trek, movi, high, art, fan...          0
#
# [50000 rows x 2 columns]

# %%
# join back

def join_back(list_input):
    return ' '.join(list_input)

# %%
df['review'] = df['review'].apply(join_back)

# %%
df
# Out:
#                                                   review  sentiment
# 0      one review mention watch 1 oz episod hook righ...          1
# 1      wonder littl product film techniqu unassum old...          1
# 2      thought wonder way spend time hot summer weeke...          1
# 3      basic famili littl boy jake think zombi closet...          0
# 4      petter mattei love time money visual stun film...          1
# ...                                                  ...        ...
# 49995  thought movi right good job creativ origin fir...          1
# 49996  bad plot bad dialogu bad act idiot direct anno...          0
# 49997  cathol taught parochi elementari school nun ta...          0
# 49998  go disagre previou comment side maltin one sec...          0
# 49999  one expect star trek movi high art fan expect ...          0
#
# [50000 rows x 2 columns]

# %%
X = df.iloc[:, 0:1].values

# %%
X.shape
# Out:
# (50000, 1)

# %%
y = df.iloc[:, -1].values

# %%
# import sys
# !{sys.executable} -m pip install scikit-learn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 6.1 MB/s eta 0:00:00MB/s eta 0:00:01:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.4/22.4 MB 9.6 MB/s eta 0:00:000:00:01m eta 0:00:01
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python3.10 -m pip install --upgrade pip

# %%
# vactorize

from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer()

# %%
X = cv.fit_transform(df['review'])

# %%
import joblib
joblib.dump(cv, "vectorizer.pkl")
# Out:
# ['vectorizer.pkl']

# %%
X = X.toarray()

# %%
X.shape
# Out:
# (50000, 73392)

# %%
X[0].max()
# Out:
# np.int64(6)

# %%
y = df.iloc[:, -1].values

# %%
y.shape
# Out:
# (50000,)

# %%
type(X), type(y)
# Out:
# (numpy.ndarray, numpy.ndarray)

# %%
X.shape, y.shape
# Out:
# ((50000, 73392), (50000,))

# %%
sparsity = 100.0 * (X == 0).sum() / X.size
sparsity
# Out:
# np.float64(50.0)

# %%
from scipy import sparse

X = sparse.csr_matrix(X)

# %%
# train_test_split

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X_train.shape
# Out:
# (40000, 73392)

# %%
y_train
# Out:
# array([1, 1, 0, ..., 1, 1, 0], shape=(40000,))

# %%
X_test
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 942900 stored elements and shape (10000, 73392)>

# %%
y_test
# Out:
# array([0, 1, 0, ..., 1, 0, 0], shape=(10000,))

# %%
# model training

from sklearn.naive_bayes import MultinomialNB, BernoulliNB
from sklearn.linear_model import LogisticRegression, SGDClassifier, RidgeClassifier, PassiveAggressiveClassifier
from sklearn.svm import LinearSVC

# %%
clf2 = MultinomialNB(alpha=1.0)
clf3 = BernoulliNB(alpha=1.0)
clf4 = LogisticRegression(solver='saga', max_iter=1000)
clf5 = LinearSVC(max_iter=5000)
clf6 = SGDClassifier(loss='log_loss', max_iter=1000, tol=1e-3)
clf7 = RidgeClassifier(alpha=1.0, solver='auto')
clf8 = PassiveAggressiveClassifier(max_iter=1000, tol=1e-3, early_stopping=False)

# %%
clf2.fit(X_train, y_train)
clf3.fit(X_train, y_train)
clf4.fit(X_train, y_train)
clf5.fit(X_train, y_train)
clf6.fit(X_train, y_train)
clf7.fit(X_train, y_train)
clf8.fit(X_train, y_train)
# Out:
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# PassiveAggressiveClassifier()

# %%
y_pred2 = clf2.predict(X_test)
y_pred3 = clf3.predict(X_test)
y_pred4 = clf4.predict(X_test)
y_pred5 = clf5.predict(X_test)
y_pred6 = clf6.predict(X_test)
y_pred7 = clf7.predict(X_test)
y_pred8 = clf8.predict(X_test)

# %%
# check accuracy score

from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, y_pred2), accuracy_score(y_test, y_pred3), accuracy_score(y_test, y_pred4), accuracy_score(y_test, y_pred5), accuracy_score(y_test, y_pred6), accuracy_score(y_test, y_pred7), accuracy_score(y_test, y_pred8)
# Out:
# (0.8541, 0.8527, 0.8817, 0.8581, 0.8813, 0.8102, 0.8609)

# %% [markdown]
# ## applying gridsearchcv on LogisticRegression on parameter C (Regularization strength)

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid_lr = {
    'C': [0.01, 0.1, 1, 5, 10],
    'solver': ['saga'],
    'max_iter': [1000]
}

grid_lr = GridSearchCV(LogisticRegression(), param_grid_lr, cv=5, scoring='accuracy')

# %%
grid_lr.fit(X_train, y_train)
# Out:
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# ...

# %%
grid_lr.best_params_, grid_lr.best_score_
# Out:
# ({'C': 0.1, 'max_iter': 1000, 'solver': 'saga'},
#  np.float64(0.8870000000000001))

# %% [markdown]
# ## applying GridSearCV on LinearSVC - tune C

# %%
param_grid_svc = {
    'C': [0.01, 0.1, 1, 5, 10],
    'max_iter': [5000]
}

grid_svc = GridSearchCV(LinearSVC(), param_grid_svc, cv=5, scoring='accuracy')
grid_svc.fit(X_train, y_train)
# Out:
# /opt/homebrew/lib/python3.10/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/svm/_base.py:1250: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# ...

# %%
grid_svc.best_params_, grid_svc.best_score_
# Out:
# ({'C': 0.01, 'max_iter': 5000}, np.float64(0.88645))

# %% [markdown]
# ## apply Grid search on multinomialNB - twig alpha

# %%
param_grid_nb = {
    'alpha': [0.01, 0.1, 0.5, 1.0, 5.0]
}

grid_nb = GridSearchCV(MultinomialNB(), param_grid_nb, cv=5, scoring='accuracy')
grid_nb.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=MultinomialNB(),
#              param_grid={'alpha': [0.01, 0.1, 0.5, 1.0, 5.0]},
#              scoring='accuracy')

# %%
grid_nb.best_params_, grid_nb.best_estimator_, grid_nb.best_score_
# Out:
# ({'alpha': 1.0}, MultinomialNB(), np.float64(0.8537250000000001))

# %% [markdown]
# ## apply grid search on SGDClassifier

# %%
param_grid_sgd = {
    'loss': ['hinge', 'log_loss'],
    'penalty': ['l2', 'l1', 'elasticnet'],
    'alpha': [1e-4, 1e-3, 1e-2],
    'max_iter': [1000]
}

grid_sgd = GridSearchCV(SGDClassifier(), param_grid_sgd, cv=5, scoring='accuracy')
grid_sgd.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=SGDClassifier(),
#              param_grid={'alpha': [0.0001, 0.001, 0.01],
#                          'loss': ['hinge', 'log_loss'], 'max_iter': [1000],
#                          'penalty': ['l2', 'l1', 'elasticnet']},
#              scoring='accuracy')

# %%
grid_sgd.best_params_, grid_sgd.best_score_
# Out:
# ({'alpha': 0.001, 'loss': 'log_loss', 'max_iter': 1000, 'penalty': 'l2'},
#  np.float64(0.887575))

# %% [markdown]
# ## retraining the models - Logistic, LinearSVC, MultinomialNB, SGDclassifier

# %%
lr = LogisticRegression(C=0.1, max_iter=1000, solver='saga')
lr.fit(X_train, y_train)

lsvc = LinearSVC(C=0.01, max_iter=5000)
lsvc.fit(X_train, y_train)

mnb = MultinomialNB(alpha=1.0)
mnb.fit(X_train, y_train)

sgd = SGDClassifier(alpha=0.001, loss='log_loss', max_iter=1000, penalty='l2')
sgd.fit(X_train, y_train)
# Out:
# SGDClassifier(alpha=0.001, loss='log_loss')

# %%
from sklearn.metrics import accuracy_score

# Predictions
y_pred_lr = lr.predict(X_test)
y_pred_lsvc = lsvc.predict(X_test)
y_pred_mnb = mnb.predict(X_test)
y_pred_sgd = sgd.predict(X_test)

# Accuracy
acc_lr = accuracy_score(y_test, y_pred_lr)
acc_lsvc = accuracy_score(y_test, y_pred_lsvc)
acc_mnb = accuracy_score(y_test, y_pred_mnb)
acc_sgd = accuracy_score(y_test, y_pred_sgd)

# Display all
print("LogisticRegression     :", round(acc_lr * 100, 2), "%")
print("LinearSVC              :", round(acc_lsvc * 100, 2), "%")
print("MultinomialNB          :", round(acc_mnb * 100, 2), "%")
print("SGDClassifier (log_loss):", round(acc_sgd * 100, 2), "%")
# Out:
# LogisticRegression     : 88.64 %
# LinearSVC              : 88.46 %
# MultinomialNB          : 85.41 %
# SGDClassifier (log_loss): 88.63 %

# %% [markdown]
# ## applying stacking-
#
# - base models - SGD, LR, LinearSVC
# - meta model - LR

# %%
from sklearn.ensemble import StackingClassifier

# %%
# Base learners (level-0 models)
base_learners = [
    ('sgd', SGDClassifier(alpha=0.001, loss='log_loss', penalty='l2', max_iter=1000)),
    ('logreg', LogisticRegression(C=0.1, solver='saga', max_iter=1000)),
    ('lsvc', LinearSVC(C=0.01, max_iter=5000)),
    ('mnb', MultinomialNB(alpha=1.0))
]

# Meta learner (level-1 model)
meta_model = LogisticRegression(solver='lbfgs', max_iter=1000)

# %%
# Stacking classifier
stacked_clf = StackingClassifier(
    estimators=base_learners,
    final_estimator=meta_model,
    cv=5,
    n_jobs=-1,
    verbose=1
)

# Fit the stacking classifier
stacked_clf.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    0.4s remaining:    0.5s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.4s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    2.4s remaining:    3.6s
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    0.8s remaining:    1.2s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.9s finished
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    3.2s finished
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:   33.4s remaining:   50.2s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   34.8s finished
# StackingClassifier(cv=5,
# ...

# %%
stacked_ypred = stacked_clf.predict(X_test)

# %%
accuracy_score(y_test, stacked_ypred)
# Out:
# 0.8912

# %%
import joblib

joblib.dump(stacked_clf, "model1.pkl")
# Out:
# ['model1.pkl']

# %% [markdown]
# ## try multi layer stacking

# %% [markdown]
# ### checking the cross val score of the 1st layer

# %%
from sklearn.model_selection import cross_val_score

# %%
cross_val_score(stacked_clf, X_train, y_train, cv=5, scoring='accuracy')
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    0.7s remaining:    1.1s
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.8s finished
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    0.1s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.1s finished
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    3.3s remaining:    5.0s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    3.6s finished
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:   24.0s remaining:   36.0s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   25.2s finished
# ...

# %% [markdown]
# ### building 1st layer

# %%
layer0 = stacked_clf

# %%
layer0.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    0.1s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    1.1s remaining:    1.6s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    1.2s finished
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    2.6s remaining:    3.9s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    3.0s finished
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:   35.9s remaining:   53.9s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:   37.8s finished
# StackingClassifier(cv=5,
# ...

# %%
layer1_train = layer0.predict(X_train).reshape(-1, 1)
layer1_test = layer0.predict(X_test).reshape(-1, 1)

# %% [markdown]
# ### building 2nd layer

# %%
from sklearn.linear_model import RidgeClassifier
from sklearn.linear_model import SGDClassifier

ridge_layer2 = RidgeClassifier()
sgd_layer2 = SGDClassifier(loss='log_loss', max_iter=1000)

# Train both on output from Layer 1
ridge_layer2.fit(layer1_train, y_train)
sgd_layer2.fit(layer1_train, y_train)

# Get their predictions on test set
pred_ridge = ridge_layer2.predict(layer1_test).reshape(-1, 1)
pred_sgd = sgd_layer2.predict(layer1_test).reshape(-1, 1)

# Stack their outputs for final layer
layer2_combined = np.hstack([pred_ridge, pred_sgd])

# %%
import joblib

joblib.dump(clf4, "model.pkl")
# Out:
# ['model.pkl']
